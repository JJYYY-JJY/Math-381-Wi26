# %% [markdown]
# <a href="https://colab.research.google.com/github/gaku-liu/Math-381-Wi26/blob/main/Homework_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Homework 5, due Monday, February 23**
#
# All problems in this homework should be done by hand. Please submit an image or pdf of your solutions to Gradescope.
#
# 1. Problem 1, page 712. (all parts)
# 2. Problem 2, page 714.
# 3. Problem 5, page 722.
# 4. In the previous problem, find $E(X_1+X_2+X_3+X_4)$. Is it different in part (a) than in part (b)?
#
#  For the next problems, define the random variables $X_t$ in the Markov chain, list what the states are, and give the transition probability matrix.
#
# 5. Problem 1, page 927.
# 6. Problem 4, page 927.
